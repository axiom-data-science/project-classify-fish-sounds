# %% [markdown]
# # Develop distinct spectrogram
#
# From my eye, the spectrograms for the different calls are not that different.  The goals of this notebook is to generate maximally distinct spectrograms for each call type.

# %%
from pathlib import Path
from IPython.display import Audio, Image

import matplotlib.pyplot as plt
import numpy as np
import torchaudio
from scipy.signal import butter, lfilter, freqz

# %%
WAV_DATA_PATH = Path('/mnt/store/data/assets/black-grouper/data/mote-usb/wav-training-samples')
TRAINING_DATA_PATH = Path('/mnt/store/data/assets/black-grouper/data/mote-usb/training-samples_1s-256fft-mean-db/wav-training-samples')

# %% [markdown]
# ## 1. Enumerating call types

# %%
call_nums = [
    0,  # Empty
    1,
    2,
    3,
    4,
    5,
    6,
    9,
    10,
    17,
    18,
    19,
    25,
    27,
    28,
    29,
    30,
    33,
    34,
    35,
    36
]
base_spec_path = {
    call: (TRAINING_DATA_PATH / f'call-{call}').glob('**/*.png')
    for call
    in call_nums
}

# %% [markdown]
# ### 1a. Evaluting grouper call types
#
# With default parameterizations, the spectrograms look very similar.

# %% [markdown]
# ### 1a. Call 0: Empty
#
# No documented call, should have same characteristics of other in terms of sampling
# frequency and spectra.

# %%
Image(next(base_spec_path[0]))

# %% [markdown]
# ### 1a. Call 1: Black Grouper call variant 1
#
# No documented call, should have same characteristics of other in terms of sampling
# frequency and spectra.

# %%
Image(next(base_spec_path[1]))

# %% [markdown]
# ### 1a. Call 2: Black Grouper call variant 2
#
# No documented call, should have same characteristics of other in terms of sampling
# frequency and spectra.

# %%
Image(next(base_spec_path[2]))

# %% [markdown]
# ### 1a. Call 3: Black Grouper call variant 3
#
# No documented call, should have same characteristics of other in terms of sampling
# frequency and spectra.

# %%
Image(next(base_spec_path[3]))

# %% [markdown]
# ### 1a. Call 4: Black Grouper call variant 4
#
# No documented call, should have same characteristics of other in terms of sampling
# frequency and spectra.

# %%
Image(next(base_spec_path[4]))

# %% [markdown]
# ### 1a. Call 5: Black Grouper call variant 5
#
# No documented call, should have same characteristics of other in terms of sampling
# frequency and spectra.

# %%
Image(next(base_spec_path[5]))

# %% [markdown]
# ### 2. Iterate on creating a more focused spectrogram.

# %%
base_wav_path = {
    call: (WAV_DATA_PATH / f'call-{call}').glob('**/*.wav')
    for call
    in call_nums
}

# %% [markdown]
# ### 2a. Call 1

# %%
sample_1_type_1 = next(base_wav_path[1])
sample_1_type_1
# Out:
# PosixPath('/mnt/store/data/assets/black-grouper/data/mote-usb/wav-training-samples/call-1/sample-0002-0001.wav')

# %%
waveform, sample_rate = torchaudio.load(sample_1_type_1)
sample_rate
# Out:
# 10000

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=1024)
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='hot')

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=1024, mode='angle')
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='hot')

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=1024, mode='phase')
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='hot')

# %% [markdown]
# ### 2a. Call 2

# %%
sample_1_type_2 = next(base_wav_path[2])
sample_1_type_2
# Out:
# PosixPath('/mnt/store/data/assets/black-grouper/data/mote-usb/wav-training-samples/call-2/sample-0000-0001.wav')

# %%
waveform, sample_rate = torchaudio.load(sample_1_type_2)
sample_rate
# Out:
# 10000

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=1024)
ax.set_axis_off()

# %%
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='hot')

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=1024, mode='angle')
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='hot')

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=1024, mode='phase')
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='hot')

# %% [markdown]
# ### 2a. Call 3

# %%
sample_1_type_3 = next(base_wav_path[3])
sample_1_type_3
# Out:
# PosixPath('/mnt/store/data/assets/black-grouper/data/mote-usb/wav-training-samples/call-3/sample-0008-0000.wav')

# %%
waveform, sample_rate = torchaudio.load(sample_1_type_3)
sample_rate
# Out:
# 10000

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=1024)
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='gray')

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=1024, mode='phase')
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='gray')

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=1024, mode='angle')
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='gray')

# %% [markdown]
# ## 2. Explore spectrograms with matplotlib / scipy
#
# ### 2b. NFFTs

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=256, cmap='hot')
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='hot')

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=512, cmap='hot')
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='hot')

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=1024, cmap='hot')
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='hot')

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=2048, cmap='hot')
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='hot')

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=4096, cmap='hot')
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='hot')

# %% [markdown]
# ### 2c. Detrend

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=256, cmap='hot', detrend='mean')
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='hot')

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=256, cmap='hot', detrend='linear')
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='hot')

# %% [markdown]
# ### 2d. Scale

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=256, cmap='hot', scale='dB')
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='hot')

# %% [markdown]
# ### 2e. Compare

# %%
waveform, sample_rate = torchaudio.load(next(base_wav_path[1]))

fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=256, cmap='hot', detrend='mean', scale='dB')
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='hot')

# %%
waveform, sample_rate = torchaudio.load(next(base_wav_path[2]))

fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=256, cmap='hot', detrend='mean', scale='dB')
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='hot')

# %%
waveform, sample_rate = torchaudio.load(next(base_wav_path[3]))

fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=256, cmap='hot', detrend='mean', scale='dB')
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='hot')

# %%
waveform, sample_rate = torchaudio.load(next(base_wav_path[4]))

fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=256, cmap='hot', detrend='mean', scale='dB')
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='hot')

# %%
waveform, sample_rate = torchaudio.load(next(base_wav_path[5]))

fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=sample_rate, NFFT=256, cmap='hot', detrend='mean', scale='dB')
ax.set_axis_off()
pass_freqs = freqs < 700

# %%
img = plt.imshow(spectrum[pass_freqs, :].T, cmap='hot')

# %% [markdown]
# ## 3. Filter, then plot

# %%
# https://stackoverflow.com/questions/25191620/creating-lowpass-filter-in-scipy-understanding-methods-and-units

def butter_lowpass(cutoff, fs, order=5):
    return butter(order, cutoff, fs=fs, btype='low', analog=False)

def butter_lowpass_filter(data, cutoff, fs, order=5):
    b, a = butter_lowpass(cutoff, fs, order=order)
    y = lfilter(b, a, data)
    return y

order = 5
fs = 10_000
cutoff = 700

# %%
b, a = butter_lowpass(cutoff, fs, order)

# %%
w, h = freqz(b, a, fs=fs, worN=8000)
plt.subplot(2, 1, 1)
plt.plot(w, np.abs(h), 'b')
plt.plot(cutoff, 0.5*np.sqrt(2), 'ko')
plt.axvline(cutoff, color='k')
plt.xlim(0, 0.5*fs)
plt.title("Lowpass Filter Frequency Response")
plt.xlabel('Frequency [Hz]')
plt.grid()

# %%
T = 1
n = int(T * fs)
y = butter_lowpass_filter(waveform, cutoff, fs, order)
t = np.arange(y.shape[-1])

# %%
y.shape
# Out:
# (1, 5600)

# %%
t.shape
# Out:
# (5600,)

# %%
waveform.shape
# Out:
# torch.Size([1, 5600])

# %%
plt.subplot(2, 1, 2)
plt.plot(t, waveform[0, :], 'b-', label='data')
plt.plot(t, np.squeeze(y), 'g-', linewidth=2, label='filtered data')
plt.xlabel('Time')
plt.grid()
plt.legend()

plt.subplots_adjust(hspace=0.35)
plt.show()

# %%
waveform.shape
# Out:
# torch.Size([1, 5600])

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(y[0, :], Fs=sample_rate, NFFT=256, cmap='hot', detrend='mean', scale='dB')
#ax.set_axis_off()

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(y[0, :], Fs=1400, NFFT=256, cmap='hot', detrend='mean', scale='dB')
#ax.set_axis_off()

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(y[0, :], Fs=1400, NFFT=256, cmap='hot', scale='dB')
#ax.set_axis_off()

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(y[0, :], Fs=1400, NFFT=256, cmap='hot', scale='linear')
#ax.set_axis_off()

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(y[0, :], Fs=1400, NFFT=256, cmap='hot', scale='linear')
#ax.set_axis_off()

# %%
# !pip install -q pydub
import pydub

# %%
sample = pydub.AudioSegment.from_wav(next(base_wav_path[1]))

# %%
dir(sample)
# Out:
# ['DEFAULT_CODECS',
#  '__add__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_data',
#  '_from_safe_wav',
#  '_parse_position',
#  '_repr_html_',
#  '_spawn',
#  '_sync',
#  'append',
#  'apply_gain',
#  'apply_gain_stereo',
#  'apply_mono_filter_to_each_channel',
#  'array_type',
#  'channels',
#  'compress_dynamic_range',
#  'converter',
#  'dBFS',
#  'duration_seconds',
#  'empty',
#  'export',
#  'fade',
#  'fade_in',
#  'fade_out',
#  'ffmpeg',
#  'frame_count',
#  'frame_rate',
#  'frame_width',
#  'from_file',
# ...

# %%
sample.sample_width
# Out:
# 2

# %%
lpf = sample.low_pass_filter(700)

# %%
lpf
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
FILTERED_3S_WAV = Path('/mnt/store/data/assets/black-grouper/data/mote-usb/wav-training-samples_3s-lpf/')

# %%
base_wav_path = {
    call: (FILTERED_3S_WAV / f'call-{call}').glob('**/*.wav')
    for call
    in call_nums
}

# %%
waveform, sample_rate = torchaudio.load(next(base_wav_path[1]))

fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=1400, NFFT=1024, cmap='hot', detrend='mean', scale='linear')
#ax.set_axis_off()

# %%
waveform, sample_rate = torchaudio.load(next(base_wav_path[2]))

fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=1400, NFFT=1024, cmap='hot', detrend='mean', scale='linear')

# %%
FILTERED_100Hz_3S_WAV = Path('/mnt/store/data/assets/black-grouper/data/mote-usb/wav-training-samples_3s-lpf-100/')

# %%
base_100hz_wav_path = {
    call: (FILTERED_100Hz_3S_WAV / f'call-{call}').glob('**/*.wav')
    for call
    in call_nums
}

# %%
waveform, sample_rate = torchaudio.load(next(base_wav_path[2]))

fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=1400, NFFT=1024, cmap='hot', detrend='mean', scale='linear')

# %%
fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=1400, NFFT=256, cmap='hot', detrend='linear', scale='linear')

# %% [markdown]
# ## 100 Hz filter samples

# %%
FILTERED_100Hz_3S_WAV = Path('/mnt/store/data/assets/black-grouper/data/mote-usb/wav-training-samples_3s-lpf-100/')

# %%
base_100hz_wav_path = {
    call: (FILTERED_100Hz_3S_WAV / f'call-{call}').glob('**/*.wav')
    for call
    in call_nums
}

# %%
waveform, sample_rate = torchaudio.load(next(base_wav_path[2]))

fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=200, NFFT=1024, cmap='hot', detrend='mean', scale='linear')

# %%
waveform, sample_rate = torchaudio.load(next(base_wav_path[1]))

fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=200, NFFT=1024, cmap='hot', detrend='mean', scale='linear')

# %%
waveform, sample_rate = torchaudio.load(next(base_wav_path[3]))

fig, ax = plt.subplots(1, 1)
spectrum, freqs, time, img = ax.specgram(waveform[0, :], Fs=200, NFFT=1024, cmap='hot', detrend='mean', scale='linear')
